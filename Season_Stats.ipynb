# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/squads/bd97ac1f/St-Louis-City-Stats')

# %%
df
# Out:
# [     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Player             Nation                Pos
#  0           Roman Bürki             ch SUI                 GK
#  1            Tim Parker             us USA                 DF
#  2          Eduard Löwen             de GER                 MF
#  3        Jake Nerwinski             us USA                 DF
#  4      Indiana Vassilev             us USA                 MF
#  5          Jared Stroud             us USA              MF,FW
#  6          Kyle Hiebert             ca CAN                 DF
#  7   Nicholas Gioacchini             us USA                 FW
#  8          Njabulo Blom             za RSA                 MF
#  9                Klauss             br BRA                 FW
#  10          John Nelson             us USA                 DF
#  11         Tomáš Ostrák             cz CZE              MF,FW
#  12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
for idx,table in enumerate(df):
 print("***************************")
 print(idx)
 print(table)
# Out:
# ***************************
# 0
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df[0]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_season_stats = df[0]

# %%
df_season_stats
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_season_stats.to_excel(r'season_stats.xlsx', sheet_name='Season Stats')

# %%
df[1]
# Out:
#           Date   Time Comp           Round  Day Venue Result   GF   GA  \
# 0   2023-02-25  19:30  MLS  Regular Season  Sat  Away      W  3.0  2.0
# 1   2023-03-04  19:30  MLS  Regular Season  Sat  Home      W  3.0  1.0
# 2   2023-03-11  19:30  MLS  Regular Season  Sat  Away      W  2.0  1.0
# 3   2023-03-18  19:30  MLS  Regular Season  Sat  Home      W  3.0  0.0
# 4   2023-03-25  19:30  MLS  Regular Season  Sat  Away      W  4.0  0.0
# 5   2023-04-01  19:30  MLS  Regular Season  Sat  Home      L  0.0  1.0
# 6   2023-04-08  19:30  MLS  Regular Season  Sat  Away      L  0.0  3.0
# 7   2023-04-15  19:30  MLS  Regular Season  Sat  Home      W  5.0  1.0
# 8   2023-04-22  19:30  MLS  Regular Season  Sat  Away      D  1.0  1.0
# 9   2023-04-29  19:30  MLS  Regular Season  Sat  Home      L  1.0  2.0
# 10  2023-05-13  12:00  MLS  Regular Season  Sat  Away      L  0.0  1.0
# 11  2023-05-20  20:30  MLS  Regular Season  Sat  Home      W  4.0  0.0
# ...

# %%
df_game_stats = df[1]
df_game_stats
# Out:
#           Date   Time Comp           Round  Day Venue Result   GF   GA  \
# 0   2023-02-25  19:30  MLS  Regular Season  Sat  Away      W  3.0  2.0
# 1   2023-03-04  19:30  MLS  Regular Season  Sat  Home      W  3.0  1.0
# 2   2023-03-11  19:30  MLS  Regular Season  Sat  Away      W  2.0  1.0
# 3   2023-03-18  19:30  MLS  Regular Season  Sat  Home      W  3.0  0.0
# 4   2023-03-25  19:30  MLS  Regular Season  Sat  Away      W  4.0  0.0
# 5   2023-04-01  19:30  MLS  Regular Season  Sat  Home      L  0.0  1.0
# 6   2023-04-08  19:30  MLS  Regular Season  Sat  Away      L  0.0  3.0
# 7   2023-04-15  19:30  MLS  Regular Season  Sat  Home      W  5.0  1.0
# 8   2023-04-22  19:30  MLS  Regular Season  Sat  Away      D  1.0  1.0
# 9   2023-04-29  19:30  MLS  Regular Season  Sat  Home      L  1.0  2.0
# 10  2023-05-13  12:00  MLS  Regular Season  Sat  Away      L  0.0  1.0
# 11  2023-05-20  20:30  MLS  Regular Season  Sat  Home      W  4.0  0.0
# ...

# %%
df_game_stats.to_excel(r'game_stats.xlsx', sheet_name='Game Stats')

# %%
df[2]
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Roman Bürki             ch SUI                 GK             32-351
# 1     Benjamin Lundt             de GER                 GK             28-037
# 2        Squad Total                NaN                NaN               26.5
# 3     Opponent Total                NaN                NaN               28.0
#
#   Playing Time                    Performance        ...                  \
#             MP Starts   Min   90s          GA  GA90  ...  D   L CS   CS%
# 0           33     33  2970  33.0          42  1.27  ...  5  11  8  24.2
# 1            1      1    90   1.0           3  3.00  ...  0   1  0   0.0
# 2           34     34  3060  34.0          45  1.32  ...  5  12  8  23.5
# 3           34     34  3056  34.0          62  1.83  ...  5  17  8  23.5
#
#   Penalty Kicks                    Unnamed: 23_level_0
# ...

# %% [markdown]
# df_goalies = df[2]
# df_goalies

# %%
df_goalies.to_excel(r'goalies.xlsx', sheet_name='Goalies')

# %%
df[3]
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Roman Bürki             ch SUI                 GK             32-351
# 1     Benjamin Lundt             de GER                 GK             28-037
# 2        Squad Total                NaN                NaN               26.5
# 3     Opponent Total                NaN                NaN               28.0
#
#   Unnamed: 4_level_0 Goals               ... Goal Kicks                 \
#                  90s    GA PKA FK CK OG  ...        Att Launch% AvgLen
# 0               33.0    42   7  0  1  2  ...        245    59.6   49.0
# 1                1.0     3   0  0  0  0  ...         10    10.0   23.6
# 2               34.0    45   7  0  1  2  ...        255    57.6   48.0
# 3               34.0    62   5  2  7  3  ...        290    46.9   40.2
#
#   Crosses          Sweeper                 Unnamed: 30_level_0
# ...

# %%
df[4]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_advanced_goalkeeping = df[3]
df_advanced_goalkeeping
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Roman Bürki             ch SUI                 GK             32-351
# 1     Benjamin Lundt             de GER                 GK             28-037
# 2        Squad Total                NaN                NaN               26.5
# 3     Opponent Total                NaN                NaN               28.0
#
#   Unnamed: 4_level_0 Goals               ... Goal Kicks                 \
#                  90s    GA PKA FK CK OG  ...        Att Launch% AvgLen
# 0               33.0    42   7  0  1  2  ...        245    59.6   49.0
# 1                1.0     3   0  0  0  0  ...         10    10.0   23.6
# 2               34.0    45   7  0  1  2  ...        255    57.6   48.0
# 3               34.0    62   5  2  7  3  ...        290    46.9   40.2
#
#   Crosses          Sweeper                 Unnamed: 30_level_0
# ...

# %%
df_advanced_goalkeeping.to_excel(r'advanced_goalkeeping.xlsx', sheet_name='Advanced Goalkeeping')

# %%
df_shooting = df[4]
df_shooting
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_shooting.to_excel(r'shooting.xlsx', sheet_name='Shooting')

# %%
df[5]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_passing = df[5]
df_passing
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_passing.to_excel(r'passing.xlsx', sheet_name='Passing')

# %%
df[6]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_pass_types = df[6]
df_pass_types
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_pass_types.to_excel(r'pass_types.xlsx', sheet_name='Pass Types')

# %%
df[7]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_goal_shot_creation = df[7]
df_goal_shot_creation
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_goal_shot_creation.to_excel(r'goal_shot_creation.xlsx', sheet_name='Goal and Shot Creation')

# %%
df[8]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_defensive_actions = df[8]
df_defensive_actions
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_defensive_actions.to_excel(r'defensive_actions.xlsx', sheet_name='Defensive Actions')

# %%
df[9]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_possession = df[9]
df_possession
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_possession.to_excel(r'Possession.xlsx', sheet_name='Possession')

# %%
df[10]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_playing_time = df[10]
df_playing_time
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_playing_time.to_excel(r'playing_time.xlsx', sheet_name='Playing Time')

# %%
df[11]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_misc = df[11]
df_misc
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Player             Nation                Pos
# 0           Roman Bürki             ch SUI                 GK
# 1            Tim Parker             us USA                 DF
# 2          Eduard Löwen             de GER                 MF
# 3        Jake Nerwinski             us USA                 DF
# 4      Indiana Vassilev             us USA                 MF
# 5          Jared Stroud             us USA              MF,FW
# 6          Kyle Hiebert             ca CAN                 DF
# 7   Nicholas Gioacchini             us USA                 FW
# 8          Njabulo Blom             za RSA                 MF
# 9                Klauss             br BRA                 FW
# 10          John Nelson             us USA                 DF
# 11         Tomáš Ostrák             cz CZE              MF,FW
# 12           Rasmus Alm             se SWE              MF,FW
# ...

# %%
df_misc.to_excel(r'miscellaneous.xlsx', sheet_name='Miscellaneous')
